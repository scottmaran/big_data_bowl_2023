# %%
''' 
Notebook used to manually identify plays of interest (i.e. with interesting blocking patterns)
'''

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
pff = pd.read_csv("data/pffScoutingData.csv")
plays = pd.read_csv("data/plays.csv")
games = pd.read_csv("data/games.csv")

# %%
# https://nfl-video.com/archive/nfl_replay/nfl_2021_22/dallas_cowboys_vs_tampa_bay_buccaneers_full_game_replay_2021_nfl_week_1/47-1-0-539
game_info = games.iloc[0,:]
game_id = game_info['gameId']
week = game_info['week']

game_info
# Out:
# gameId             2021090900
# season                   2021
# week                        1
# gameDate           09/09/2021
# gameTimeEastern      20:20:00
# homeTeamAbbr               TB
# visitorTeamAbbr           DAL
# Name: 0, dtype: object

# %%
game_df = pff.query("gameId == @game_id")

game_df.head()
# Out:
#        gameId  playId  nflId    pff_role pff_positionLinedUp  pff_hit  \
# 0  2021090900      97  25511        Pass                  QB      NaN
# 1  2021090900      97  35481  Pass Route                TE-L      NaN
# 2  2021090900      97  35634  Pass Route                 LWR      NaN
# 3  2021090900      97  39985  Pass Route                HB-R      NaN
# 4  2021090900      97  40151  Pass Block                   C      NaN
#
#    pff_hurry  pff_sack  pff_beatenByDefender  pff_hitAllowed  \
# 0        NaN       NaN                   NaN             NaN
# 1        NaN       NaN                   NaN             NaN
# 2        NaN       NaN                   NaN             NaN
# 3        NaN       NaN                   NaN             NaN
# 4        NaN       NaN                   0.0             0.0
#
#    pff_hurryAllowed  pff_sackAllowed  pff_nflIdBlockedPlayer pff_blockType  \
# 0               NaN              NaN                     NaN           NaN
# ...

# %%
plays.query("gameId == 2021090900 and playId == 735")
# Out:
#         gameId  playId                                    playDescription  \
# 13  2021090900     735  (2:45) (Shotgun) D.Prescott pass short right t...
#
#     quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 13        1     2          3            DAL            TB           TB
#
#     yardlineNumber gameClock  preSnapHomeScore  preSnapVisitorScore  \
# 13              37     02:45                 7                    0
#
#    passResult  penaltyYards  prePenaltyPlayResult  playResult foulName1  \
# 13          C           NaN                     8           8       NaN
#
#     foulNFLId1 foulName2  foulNFLId2 foulName3  foulNFLId3  \
# 13         NaN       NaN         NaN       NaN         NaN
#
#     absoluteYardlineNumber offenseFormation        personnelO  defendersInBox  \
# 13                    47.0          SHOTGUN  1 RB, 1 TE, 3 WR             6.0
#
#           personnelD            dropBackType  pff_playAction pff_passCoverage  \
# ...

# %%
plays[['playId']].values[0:20]
# Out:
# array([[  97],
#        [ 137],
#        [ 187],
#        [ 282],
#        [ 349],
#        [ 410],
#        [ 434],
#        [ 456],
#        [ 480],
#        [ 509],
#        [ 559],
#        [ 583],
#        [ 687],
#        [ 735],
#        [ 764],
#        [ 788],
#        [ 869],
#        [ 925],
#        [ 947],
#        [1078]])

# %%
play_id = 1078

lineman_in_play = game_df.query("playId == @play_id")[game_df.query("playId == @play_id")['pff_blockType'].notnull()]
lineman_in_play = lineman_in_play[['gameId', 'playId', 'nflId', 'pff_role', 'pff_positionLinedUp', 'pff_blockType', 'pff_beatenByDefender']]

lineman_in_play
# Out:
#          gameId  playId  nflId    pff_role pff_positionLinedUp pff_blockType  \
# 420  2021090900    1078  37082  Pass Block                  LT            PP
# 426  2021090900    1078  42654  Pass Block                  RT            PP
# 428  2021090900    1078  46119  Pass Block                  LG            PP
# 433  2021090900    1078  47873  Pass Block                  RG            CL
# 439  2021090900    1078  52554  Pass Block                   C            PP
#
#      pff_beatenByDefender
# 420                   0.0
# 426                   0.0
# 428                   0.0
# 433                   0.0
# 439                   0.0
